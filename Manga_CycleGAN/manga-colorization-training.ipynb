# %% [markdown]
# # Import Libraries

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import json
import cv2
import matplotlib
import matplotlib.pyplot as plt
import scipy
import warnings
import shutil
import random
import shutil 

from PIL import Image
from tqdm import tqdm
from distutils.dir_util import copy_tree

# %% [markdown]
# # Split the dataset

# %%
cl_1 = 'Manga/blackclover/colored/'
cl_2 = 'Manga/bukonohero/colored/'
cl_3 = 'Manga/onepiece/colored/'

# %%
print(len(os.listdir(cl_1)))
print(len(os.listdir(cl_2)))
print(len(os.listdir(cl_3)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(len(os.listdir(cl_1)))
#       2 print(len(os.listdir(cl_2)))
#       3 print(len(os.listdir(cl_3)))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Manga/blackclover/colored/'

# %%
bw_1 = 'Manga/blackclover/grayscale/'
bw_2 = 'Manga/bukonohero/grayscale/'
bw_3 = 'Manga/onepiece/grayscale/'

target_dir_bw = 'manga_dataset/grayscale/'

file_names_bw_1 = os.listdir(bw_1)
file_names_bw_2 = os.listdir(bw_2)
file_names_bw_3 = os.listdir(bw_3)

for file_name in tqdm(file_names_bw_1, 'blackclover grayscale'):
    shutil.copy(os.path.join(bw_1, file_name), target_dir_bw)
    os.rename(os.path.join(target_dir_bw, file_name), os.path.join(target_dir_bw, str('blackclover_bw') + file_name))
    
for file_name in tqdm(file_names_bw_2, 'bukonohero grayscale'):
    shutil.copy(os.path.join(bw_2, file_name), target_dir_bw)
    os.rename(os.path.join(target_dir_bw, file_name), os.path.join(target_dir_bw, str('bukonohero_bw') + file_name))
    
for file_name in tqdm(file_names_bw_3, 'onepiece grayscale'):
    shutil.copy(os.path.join(bw_3, file_name), target_dir_bw)
    os.rename(os.path.join(target_dir_bw, file_name), os.path.join(target_dir_bw, str('onepiece_bw') + file_name))
# Out:
# blackclover grayscale: 100%|██████████| 1068/1068 [00:00<00:00, 1386.17it/s]
# bukonohero grayscale: 100%|██████████| 1094/1094 [00:00<00:00, 1590.13it/s]
# onepiece grayscale: 100%|██████████| 2679/2679 [00:02<00:00, 1029.66it/s]

# %%
print(len(os.listdir('./manga_dataset/colored/')))
print(len(os.listdir('./manga_dataset/grayscale/')))
# Out:
# 3577
# 4841

# %%
# colored
colored_files =  os.listdir('./manga_dataset/colored/')

# grayscale
grayscale_files =  os.listdir('./manga_dataset/grayscale/')
grayscale_files = grayscale_files[:3577]

# %%
# Load the image
image1 = cv2.imread(os.path.join('./manga_dataset/colored/',colored_files[0]))

# OpenCV loads images in BGR format by default. Convert it to RGB format.
image_rgb = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

# Use matplotlib to display the image
plt.imshow(image_rgb)
plt.title('Displayed Image')
plt.axis('off')  # Hide the axis
plt.show()

# %%
# Load the image
image2 = cv2.imread(os.path.join('./manga_dataset/grayscale/',grayscale_files[0]))

# OpenCV loads images in BGR format by default. Convert it to RGB format.
image_rgb = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# Use matplotlib to display the image
plt.imshow(image_rgb)
plt.title('Displayed Image')
plt.axis('off')  # Hide the axis
plt.show()

# %%
from collections import OrderedDict

import torch
from torch import nn, optim

from ignite.engine import *
from ignite.handlers import *
from ignite.metrics import *
from ignite.metrics.regression import *
from ignite.utils import *

# create default evaluator for doctests

def eval_step(engine, batch):
    return batch

default_evaluator = Engine(eval_step)

# create default optimizer for doctests

param_tensor = torch.zeros([1], requires_grad=True)
default_optimizer = torch.optim.SGD([param_tensor], lr=0.1)

# create default trainer for doctests
# as handlers could be attached to the trainer,
# each test must define his own trainer using `.. testsetup:`

def get_default_trainer():

    def train_step(engine, batch):
        return batch

    return Engine(train_step)

# create default model for doctests

default_model = nn.Sequential(OrderedDict([
    ('base', nn.Linear(1479, 2)),
    ('fc', nn.Linear(2, 1))
]))

manual_seed(666)

# %%
metric = FID(num_features=1, feature_extractor=default_model)
metric.attach(default_evaluator, "fid")
x = torch.tensor(image1,dtype=torch.float32).permute(2, 0, 1)
y = torch.tensor(image2,dtype=torch.float32).permute(2, 0, 1)
m = nn.ZeroPad2d((695, 0, 1015, 0))
y = m(y)

state = default_evaluator.run([[x, y]])
state
# Out:
# Current run is terminating due to exception: feature_extractor output must be a tensor of dim 2, got: 3
# Engine run is terminating due to exception: feature_extractor output must be a tensor of dim 2, got: 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 8
#       5 m = nn.ZeroPad2d((695, 0, 1015, 0))
#       6 y = m(y)
# ----> 8 state = default_evaluator.run([[x, y]])
#       9 state
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:889, in Engine.run(self, data, max_epochs, epoch_length)
#     886     self.state.dataloader = data
#     888 if self.interrupt_resume_enabled:
# --> 889     return self._internal_run()
#     890 else:
#     891     return self._internal_run_legacy()
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:932, in Engine._internal_run(self)
#     930     self._internal_run_generator = self._internal_run_as_gen()
#     931 try:
# --> 932     return next(self._internal_run_generator)
#     933 except StopIteration as out:
#     934     self._internal_run_generator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:990, in Engine._internal_run_as_gen(self)
#     988     self._dataloader_iter = None
#     989     self.logger.error(f"Engine run is terminating due to exception: {e}")
# --> 990     self._handle_exception(e)
#     992 self._dataloader_iter = None
#     993 return self.state
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:644, in Engine._handle_exception(self, e)
#     642     self._fire_event(Events.EXCEPTION_RAISED, e)
#     643 else:
# --> 644     raise e
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:956, in Engine._internal_run_as_gen(self)
#     953 if self._dataloader_iter is None:
#     954     self._setup_engine()
# --> 956 epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#     958 # time is available for handlers but must be updated after fire
#     959 self.state.times[Events.EPOCH_COMPLETED.name] = epoch_time_taken
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:1096, in Engine._run_once_on_dataset_as_gen(self)
#    1094 except Exception as e:
#    1095     self.logger.error(f"Current run is terminating due to exception: {e}")
# -> 1096     self._handle_exception(e)
#    1098 return time.time() - start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:644, in Engine._handle_exception(self, e)
#     642     self._fire_event(Events.EXCEPTION_RAISED, e)
#     643 else:
# --> 644     raise e
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:1078, in Engine._run_once_on_dataset_as_gen(self)
#    1075 yield from self._maybe_terminate_or_interrupt()
#    1077 self.state.output = self._process_function(self, self.state.batch)
# -> 1078 self._fire_event(Events.ITERATION_COMPLETED)
#    1079 yield from self._maybe_terminate_or_interrupt()
#    1081 if self.state.epoch_length is not None and iter_counter == self.state.epoch_length:
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/engine/engine.py:431, in Engine._fire_event(self, event_name, *event_args, **event_kwargs)
#     429 kwargs.update(event_kwargs)
#     430 first, others = ((args[0],), args[1:]) if (args and args[0] == self) else ((), args)
# --> 431 func(*first, *(event_args + others), **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/metrics/metric.py:405, in Metric.iteration_completed(self, engine)
#     403         self.update((tensor_o1, tensor_o2))
#     404 else:
# --> 405     self.update(output)
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/metrics/metric.py:797, in reinit__is_reduced.<locals>.wrapper(self, *args, **kwargs)
#     795 @wraps(func)
#     796 def wrapper(self: Metric, *args: Any, **kwargs: Any) -> None:
# --> 797     func(self, *args, **kwargs)
#     798     if "_result" in self.__dict__:
#     799         self._result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/metrics/gan/fid.py:234, in FID.update(self, output)
#     231 @reinit__is_reduced
#     232 def update(self, output: Sequence[torch.Tensor]) -> None:
#     233     train, test = output
# --> 234     train_features = self._extract_features(train)
#     235     test_features = self._extract_features(test)
#     237     if train_features.shape[0] != test_features.shape[0] or train_features.shape[1] != test_features.shape[1]:
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/metrics/gan/utils.py:99, in _BaseInceptionMetric._extract_features(self, inputs)
#      97 with torch.no_grad():
#      98     outputs = self._feature_extractor(inputs).to(self._device, dtype=torch.float64)
# ---> 99 self._check_feature_shapes(outputs)
#     101 return outputs
#
# File ~/anaconda3/lib/python3.11/site-packages/ignite/metrics/gan/utils.py:81, in _BaseInceptionMetric._check_feature_shapes(self, samples)
#      79 def _check_feature_shapes(self, samples: torch.Tensor) -> None:
#      80     if samples.dim() != 2:
# ---> 81         raise ValueError(f"feature_extractor output must be a tensor of dim 2, got: {samples.dim()}")
#      83     if samples.shape[0] == 0:
#      84         raise ValueError(f"Batch size should be greater than one, got: {samples.shape[0]}")
#
# ValueError: feature_extractor output must be a tensor of dim 2, got: 3

# %%
print(state.metrics["fid"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 print(state.metrics["fid"])
#
# AttributeError: 'NoneType' object has no attribute 'metrics'

# %%
print(x.shape)
print(y.shape)
# Out:
# torch.Size([3, 2160, 1479])
# torch.Size([3, 2160, 1479])

# %%
#m = nn.ZeroPad2d((2))
# # padding_left, 
# padding_right, 
# padding_top, 
# padding_bottom)
input = torch.randn(3, 1145, 784)

# using different paddings for different sides

m(input)
print(input.shape)
print(m(input).shape)
# Out:
# torch.Size([3, 1145, 784])
# torch.Size([3, 2160, 1474])

# %%
# shuffle the dataset
temp = list(zip(colored_files, grayscale_files))

random.shuffle(temp)
res1, res2 = zip(*temp)

# res1 and res2 come out as tuples, and so must be converted to lists.
colored, grayscale = list(res1), list(res2)

print(colored[0:5])
print(grayscale[0:5])
# Out:
# ['blackclover_cl408.png', 'onepiece_cl1056.png', 'onepiece_cl24.png', 'onepiece_cl876.png', 'bukonohero_cl717.png']
# ['onepiece_bw1960.png', 'onepiece_bw544.png', 'blackclover_bw320.png', 'onepiece_bw920.png', 'onepiece_bw1271.png']

# %%
#split the dataset 0.8 for training

#training colored
train_cl = []
for i in tqdm(range(int(0.0*len(colored)), int(0.8*len(colored)))):
    train_cl.append(colored[i])
    
#testing grayscale
test_cl = []
for i in tqdm(range(int(0.8*len(colored)), int(1.0*len(colored)))):
    test_cl.append(colored[i])
# Out:
# 100%|██████████| 2861/2861 [00:00<00:00, 1796392.78it/s]
# 100%|██████████| 716/716 [00:00<00:00, 1634796.77it/s]

# %%
print(train_cl[-3:None])
print(test_cl[0:3])
# Out:
# ['blackclover_cl701.png', 'blackclover_cl652.png', 'onepiece_cl339.png']
# ['onepiece_cl604.png', 'bukonohero_cl160.png', 'onepiece_cl1238.png']

# %%
#training grayscale
train_bw = []
for i in tqdm(range(int(0.0*len(grayscale)), int(0.8*len(grayscale)))):
    train_bw.append(grayscale[i])
    
#testing grayscale
test_bw = []
for i in tqdm(range(int(0.8*len(grayscale)), int(1.0*len(grayscale)))):
    test_bw.append(grayscale[i])
# Out:
# 100%|██████████| 2861/2861 [00:00<00:00, 2547209.46it/s]
# 100%|██████████| 716/716 [00:00<00:00, 2119351.92it/s]

# %%
print(train_bw[-3:None])
print(test_bw[0:3])
# Out:
# ['blackclover_bw848.png', 'bukonohero_bw961.png', 'onepiece_bw9.png']
# ['bukonohero_bw583.png', 'onepiece_bw810.png', 'onepiece_bw1634.png']

# %%
def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)

# %%
# copy the train dataset to unpaired image dataset path
for i in tqdm(range(len(train_cl)), 'copying train colored and grayscale'):
    # Source path 
    src1 = find(str(train_bw[i]), './manga_dataset/grayscale/')
    src2 = find(str(train_cl[i]), './manga_dataset/colored/')

    # Destination path 
    dest1 = 'manga_dataset/train_test/trainA/'
    dest2 = 'manga_dataset/train_test/trainB/'

    # Copy the content of source to destination 
    shutil.copy(src1, dest1) 
    shutil.copy(src2, dest2)
# Out:
# copying train colored and grayscale: 100%|██████████| 2861/2861 [00:16<00:00, 172.55it/s]

# %%
# copy the test dataset to unpaired image dataset path
for i in tqdm(range(len(test_cl)), 'copying test colored and grayscale'):
    # Source path 
    src1 = find(str(test_bw[i]), './manga_dataset/grayscale/')
    src2 = find(str(test_cl[i]), './manga_dataset/colored/')

    # Destination path 
    dest1 = 'manga_dataset/train_test/testA/'
    dest2 = 'manga_dataset/train_test/testB/'

    # Copy the content of source to destination 
    shutil.copy(src1, dest1) 
    shutil.copy(src2, dest2)
# Out:
# copying test colored and grayscale: 100%|██████████| 716/716 [00:04<00:00, 172.69it/s]

# %% [markdown]
# # Install MMGeneration

# %%
# Check Pytorch installation
import torch
print(torch.__version__)
# Out:
# 2.3.0

# %%
# !conda install pytorch==1.6.0 torchvision==0.7.0 cudatoolkit=10.1 -c pytorch -y

# install the latest mmcv
# pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/{cu_version}/{torch_version}/index.html
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu101/torch1.6.0/index.html

# install mmgeneration
# !rm -rf mmgeneration
# !git clone https://github.com/open-mmlab/mmgeneration.git
# %cd mmgeneration
# !pip install -r requirements.txt
# !pip install -v -e .
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "HEAD /conda-forge/noarch/repodata.json HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "HEAD /tczhangzhi/noarch/repodata.json HTTP/1.1" 200 0
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
#  - tczhangzhi
# Platform: osx-arm64
# Collecting package metadata (repodata.json): - DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# | DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /tczhangzhi/noarch/repodata.json HTTP/1.1" 304 0
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/osx-arm64/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/repodata.json HTTP/1.1" 304 0
# done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - cudatoolkit=10.1*
#   - pytorch==1.6.0
#   - torchvision==0.7.0
#
# Current channels:
#
#   - https://conda.anaconda.org/pytorch
#   - defaults
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://conda.anaconda.org/conda-forge/osx-arm64
#   - https://conda.anaconda.org/tczhangzhi/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu101/torch1.6.0/index.html
# Requirement already satisfied: mmcv-full in /Users/leo/anaconda3/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: addict in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcv-full) (2.4.0)
# Requirement already satisfied: numpy in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcv-full) (1.23.5)
# Requirement already satisfied: packaging in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcv-full) (23.0)
# Requirement already satisfied: Pillow in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcv-full) (10.0.1)
# Requirement already satisfied: pyyaml in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcv-full) (6.0)
# Requirement already satisfied: yapf in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcv-full) (0.31.0)
# Cloning into 'mmgeneration'...
# remote: Enumerating objects: 9006, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 9006 (delta 62), reused 90 (delta 45), pack-reused 8876
# Receiving objects: 100% (9006/9006), 27.20 MiB | 18.42 MiB/s, done.
# Resolving deltas: 100% (6260/6260), done.
# /Users/leo/Desktop/Manga-Colorization/Manga_CycleGAN/mmgeneration
# Requirement already satisfied: mmcls in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 1)) (0.25.0)
# Requirement already satisfied: ninja in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 2)) (1.11.1.1)
# Requirement already satisfied: numpy in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 3)) (1.23.5)
# Requirement already satisfied: prettytable in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 4)) (3.10.0)
# Requirement already satisfied: requests in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 5)) (2.31.0)
# Requirement already satisfied: scikit-image in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 6)) (0.20.0)
# Requirement already satisfied: scipy in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 7)) (1.10.1)
# Requirement already satisfied: tqdm in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 8)) (4.66.1)
# Requirement already satisfied: yapf in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/runtime.txt (line 9)) (0.31.0)
# Requirement already satisfied: coverage<7.0.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/tests.txt (line 1)) (6.5.0)
# Requirement already satisfied: flake8 in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/tests.txt (line 3)) (6.0.0)
# Requirement already satisfied: interrogate in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/tests.txt (line 4)) (1.7.0)
# Requirement already satisfied: isort==4.3.21 in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/tests.txt (line 5)) (4.3.21)
# Requirement already satisfied: pytest in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/tests.txt (line 6)) (7.4.0)
# Requirement already satisfied: pytest-runner in /Users/leo/anaconda3/lib/python3.11/site-packages (from -r requirements/tests.txt (line 7)) (6.0.1)
# Requirement already satisfied: matplotlib>=3.1.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcls->-r requirements/runtime.txt (line 1)) (3.7.1)
# Requirement already satisfied: packaging in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcls->-r requirements/runtime.txt (line 1)) (23.0)
# Requirement already satisfied: wcwidth in /Users/leo/anaconda3/lib/python3.11/site-packages (from prettytable->-r requirements/runtime.txt (line 4)) (0.2.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->-r requirements/runtime.txt (line 5)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->-r requirements/runtime.txt (line 5)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->-r requirements/runtime.txt (line 5)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->-r requirements/runtime.txt (line 5)) (2024.2.2)
# Requirement already satisfied: networkx>=2.8 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->-r requirements/runtime.txt (line 6)) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->-r requirements/runtime.txt (line 6)) (10.0.1)
# Requirement already satisfied: imageio>=2.4.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->-r requirements/runtime.txt (line 6)) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->-r requirements/runtime.txt (line 6)) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->-r requirements/runtime.txt (line 6)) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->-r requirements/runtime.txt (line 6)) (0.3)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from flake8->-r requirements/tests.txt (line 3)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.11.0,>=2.10.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from flake8->-r requirements/tests.txt (line 3)) (2.10.0)
# Requirement already satisfied: pyflakes<3.1.0,>=3.0.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from flake8->-r requirements/tests.txt (line 3)) (3.0.1)
# Requirement already satisfied: attrs in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->-r requirements/tests.txt (line 4)) (22.1.0)
# Requirement already satisfied: click>=7.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->-r requirements/tests.txt (line 4)) (8.0.4)
# Requirement already satisfied: colorama in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->-r requirements/tests.txt (line 4)) (0.4.6)
# Requirement already satisfied: py in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->-r requirements/tests.txt (line 4)) (1.11.0)
# Requirement already satisfied: tabulate in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->-r requirements/tests.txt (line 4)) (0.8.10)
# Requirement already satisfied: iniconfig in /Users/leo/anaconda3/lib/python3.11/site-packages (from pytest->-r requirements/tests.txt (line 6)) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/leo/anaconda3/lib/python3.11/site-packages (from pytest->-r requirements/tests.txt (line 6)) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->-r requirements/runtime.txt (line 1)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->-r requirements/runtime.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->-r requirements/runtime.txt (line 1)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->-r requirements/runtime.txt (line 1)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->-r requirements/runtime.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->-r requirements/runtime.txt (line 1)) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/leo/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->mmcls->-r requirements/runtime.txt (line 1)) (1.16.0)
# Using pip 24.0 from /Users/leo/anaconda3/lib/python3.11/site-packages/pip (python 3.11)
# Obtaining file:///Users/leo/Desktop/Manga-Colorization/Manga_CycleGAN/mmgeneration
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
#   creating /private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info
#   writing /private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info/PKG-INFO
#   writing dependency_links to /private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info/dependency_links.txt
#   writing requirements to /private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info/requires.txt
#   writing top-level names to /private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info/top_level.txt
#   writing manifest file '/private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info/SOURCES.txt'
#   reading manifest file '/private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'mmgen/model-index.yml'
#   warning: no files found matching '*.py' under directory 'mmgen/configs'
#   warning: no files found matching '*.yml' under directory 'mmgen/configs'
#   warning: no files found matching '*.sh' under directory 'mmgen/tools'
#   warning: no files found matching '*.py' under directory 'mmgen/tools'
#   warning: no files found matching 'mmgen/VERSION'
#   warning: no files found matching 'mmgen/.mim/model-index.yml'
#   warning: no files found matching 'mmgen/.mim/demo/*/*'
#   warning: no files found matching '*.py' under directory 'mmgen/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmgen/.mim/configs'
#   warning: no files found matching '*.sh' under directory 'mmgen/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmgen/.mim/tools'
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file '/private/var/folders/yd/zz3pvt3n3yb2gz0g6xjn68th0000gn/T/pip-pip-egg-info-qjjkc7vb/mmgen.egg-info/SOURCES.txt'
# done
# Requirement already satisfied: mmcls in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (0.25.0)
# Requirement already satisfied: ninja in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (1.11.1.1)
# Requirement already satisfied: numpy in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (1.23.5)
# Requirement already satisfied: prettytable in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (3.10.0)
# Requirement already satisfied: requests in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (2.31.0)
# Requirement already satisfied: scikit-image in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (0.20.0)
# Requirement already satisfied: scipy in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (1.10.1)
# Requirement already satisfied: tqdm in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (4.66.1)
# Requirement already satisfied: yapf in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (0.31.0)
# Requirement already satisfied: coverage<7.0.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (6.5.0)
# Requirement already satisfied: flake8 in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (6.0.0)
# Requirement already satisfied: interrogate in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (1.7.0)
# Requirement already satisfied: isort==4.3.21 in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (4.3.21)
# Requirement already satisfied: pytest in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (7.4.0)
# Requirement already satisfied: pytest-runner in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmgen==0.7.3) (6.0.1)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from flake8->mmgen==0.7.3) (0.7.0)
# Requirement already satisfied: pycodestyle<2.11.0,>=2.10.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from flake8->mmgen==0.7.3) (2.10.0)
# Requirement already satisfied: pyflakes<3.1.0,>=3.0.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from flake8->mmgen==0.7.3) (3.0.1)
# Requirement already satisfied: attrs in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->mmgen==0.7.3) (22.1.0)
# Requirement already satisfied: click>=7.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->mmgen==0.7.3) (8.0.4)
# Requirement already satisfied: colorama in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->mmgen==0.7.3) (0.4.6)
# Requirement already satisfied: py in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->mmgen==0.7.3) (1.11.0)
# Requirement already satisfied: tabulate in /Users/leo/anaconda3/lib/python3.11/site-packages (from interrogate->mmgen==0.7.3) (0.8.10)
# Requirement already satisfied: matplotlib>=3.1.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcls->mmgen==0.7.3) (3.7.1)
# Requirement already satisfied: packaging in /Users/leo/anaconda3/lib/python3.11/site-packages (from mmcls->mmgen==0.7.3) (23.0)
# Requirement already satisfied: wcwidth in /Users/leo/anaconda3/lib/python3.11/site-packages (from prettytable->mmgen==0.7.3) (0.2.12)
# Requirement already satisfied: iniconfig in /Users/leo/anaconda3/lib/python3.11/site-packages (from pytest->mmgen==0.7.3) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/leo/anaconda3/lib/python3.11/site-packages (from pytest->mmgen==0.7.3) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->mmgen==0.7.3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->mmgen==0.7.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->mmgen==0.7.3) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/leo/anaconda3/lib/python3.11/site-packages (from requests->mmgen==0.7.3) (2024.2.2)
# Requirement already satisfied: networkx>=2.8 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->mmgen==0.7.3) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->mmgen==0.7.3) (10.0.1)
# Requirement already satisfied: imageio>=2.4.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->mmgen==0.7.3) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->mmgen==0.7.3) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->mmgen==0.7.3) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from scikit-image->mmgen==0.7.3) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->mmgen==0.7.3) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->mmgen==0.7.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->mmgen==0.7.3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->mmgen==0.7.3) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->mmgen==0.7.3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/leo/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.0->mmcls->mmgen==0.7.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/leo/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->mmcls->mmgen==0.7.3) (1.16.0)
# Installing collected packages: mmgen
#   Running setup.py develop for mmgen
#     Running command python setup.py develop
#     running develop
#     /Users/leo/anaconda3/lib/python3.11/site-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` and ``easy_install``.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://github.com/pypa/setuptools/issues/917 for details.
#             ********************************************************************************
#
#     !!
#       easy_install.initialize_options(self)
#     /Users/leo/anaconda3/lib/python3.11/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` directly.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#             ********************************************************************************
#
#     !!
#       self.initialize_options()
#     running egg_info
#     creating mmgen.egg-info
#     writing mmgen.egg-info/PKG-INFO
#     writing dependency_links to mmgen.egg-info/dependency_links.txt
#     writing requirements to mmgen.egg-info/requires.txt
#     writing top-level names to mmgen.egg-info/top_level.txt
#     writing manifest file 'mmgen.egg-info/SOURCES.txt'
#     reading manifest file 'mmgen.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching 'mmgen/model-index.yml'
#     warning: no files found matching '*.py' under directory 'mmgen/configs'
#     warning: no files found matching '*.yml' under directory 'mmgen/configs'
#     warning: no files found matching '*.sh' under directory 'mmgen/tools'
#     warning: no files found matching '*.py' under directory 'mmgen/tools'
#     warning: no files found matching 'mmgen/VERSION'
#     warning: no files found matching 'mmgen/.mim/demo/*/*'
#     adding license file 'LICENSE'
#     adding license file 'LICENSES.md'
#     writing manifest file 'mmgen.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /Users/leo/anaconda3/lib/python3.11/site-packages/mmgen.egg-link (link to .)
#     mmgen 0.7.3 is already the active version in easy-install.pth
#
#     Installed /Users/leo/Desktop/Manga-Colorization/Manga_CycleGAN/mmgeneration
# Successfully installed mmgen-0.7.3

# %%
from mmcv import collect_env
collect_env()
# Out:
# {'sys.platform': 'darwin',
#  'Python': '3.11.7 | packaged by conda-forge | (main, Dec 23 2023, 14:38:07) [Clang 16.0.6 ]',
#  'CUDA available': False,
#  'GCC': 'Apple clang version 15.0.0 (clang-1500.3.9.4)',
#  'PyTorch': '2.3.0',
#  'PyTorch compiling details': 'PyTorch built with:\n  - GCC 4.2\n  - C++ Version: 201703\n  - clang 14.0.3\n  - LAPACK is enabled (usually provided by MKL)\n  - NNPACK is enabled\n  - CPU capability usage: NO AVX\n  - Build settings: BLAS_INFO=accelerate, BUILD_TYPE=Release, CXX_COMPILER=/Applications/Xcode_14.3.1.app/Contents/Developer/Toolchains/XcodeDefault.xctoolchain/usr/bin/clang++, CXX_FLAGS= -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DUSE_PYTORCH_METAL_EXPORT -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DUSE_COREML_DELEGATE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=braced-scalar-init -Werror=range-loop-construct -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wvla-extension -Wsuggest-override -Wnewline-eof -Winconsistent-missing-override -Winconsistent-missing-destructor-override -Wno-pass-failed -Wno-error=pedantic -Wno-error=old-style-cast -Wno-error=inconsistent-missing-override -Wno-error=inconsistent-missing-destructor-override -Wconstant-conversion -Wno-invalid-partial-specialization -Wno-missing-braces -Qunused-arguments -fcolor-diagnostics -faligned-new -Wno-unused-but-set-variable -fno-math-errno -fno-trapping-math -Werror=format -DUSE_MPS -Wno-unused-private-field -Wno-missing-braces, LAPACK_INFO=accelerate, TORCH_VERSION=2.3.0, USE_CUDA=0, USE_CUDNN=OFF, USE_CUSPARSELT=OFF, USE_EIGEN_FOR_BLAS=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=OFF, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=ON, USE_OPENMP=OFF, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF, \n',
#  'TorchVision': '0.15.2a0',
#  'OpenCV': '4.6.0',
#  'MMCV': '1.7.2',
#  'MMCV Compiler': 'clang 15.0.0',
#  'MMCV CUDA Compiler': 'not available'}

# %%
# Check MMDetection installation
import mmgen
print(mmgen.__version__)

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())
# Out:
# 0.7.3
# not available
# clang 15.0.0

# %% [markdown]
# # Start training

# %%
# download pre-trained cyclegan model in winter2summer dataset
import wget

url = 'https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth'
wget.download(url, out='../')
# Out:
# '..//cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1 (1).pth'

# %%
# %%writefile configs/cyclegan/cyclegan_lsgan_resnet_in_summer2winter_b1x1_250k.py

_base_ = [
    '../_base_/models/cyclegan/cyclegan_lsgan_resnet.py',
    '../_base_/datasets/unpaired_imgs_256x256.py',
    '../_base_/default_runtime.py'
]

domain_a = 'grayscale'
domain_b = 'colored'
model = dict(
    default_domain=domain_b,
    reachable_domains=[domain_a, domain_b],
    related_domains=[domain_a, domain_b],
    gen_auxiliary_loss=[
        dict(
            type='L1Loss',
            loss_weight=10.0,
            loss_name='cycle_loss',
            data_info=dict(
                pred=f'cycle_{domain_a}', target=f'real_{domain_a}'),
            reduction='mean'),
        dict(
            type='L1Loss',
            loss_weight=10.0,
            loss_name='cycle_loss',
            data_info=dict(
                pred=f'cycle_{domain_b}',
                target=f'real_{domain_b}',
            ),
            reduction='mean'),
        dict(
            type='L1Loss',
            loss_weight=0.5,
            loss_name='id_loss',
            data_info=dict(
                pred=f'identity_{domain_a}', target=f'real_{domain_a}'),
            reduction='mean'),
        dict(
            type='L1Loss',
            loss_weight=0.5,
            loss_name='id_loss',
            data_info=dict(
                pred=f'identity_{domain_b}', target=f'real_{domain_b}'),
            reduction='mean')
    ])
dataroot = '/Users/leo/Desktop/Manga-Colorization/manga_dataset/train_test/'
train_pipeline = [
    dict(
        type='LoadImageFromFile',
        io_backend='disk',
        key=f'img_{domain_a}',
        flag='color'),
    dict(
        type='LoadImageFromFile',
        io_backend='disk',
        key=f'img_{domain_b}',
        flag='color'),
    dict(
        type='Resize',
        keys=[f'img_{domain_a}', f'img_{domain_b}'],
        scale=(256, 368),
        interpolation='bicubic'),
    dict(
        type='Crop',
        keys=[f'img_{domain_a}', f'img_{domain_b}'],
        crop_size=(368, 256),
        random_crop=True),
    dict(type='Flip', keys=[f'img_{domain_a}'], direction='horizontal'),
    dict(type='Flip', keys=[f'img_{domain_b}'], direction='horizontal'),
    dict(type='RescaleToZeroOne', keys=[f'img_{domain_a}', f'img_{domain_b}']),
    dict(
        type='Normalize',
        keys=[f'img_{domain_a}', f'img_{domain_b}'],
        to_rgb=False,
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]),
    dict(type='ImageToTensor', keys=[f'img_{domain_a}', f'img_{domain_b}']),
    dict(
        type='Collect',
        keys=[f'img_{domain_a}', f'img_{domain_b}'],
        meta_keys=[f'img_{domain_a}_path', f'img_{domain_b}_path'])
]

test_pipeline = [
    dict(
        type='LoadImageFromFile',
        io_backend='disk',
        key=f'img_{domain_a}',
        flag='color'),
    dict(
        type='LoadImageFromFile',
        io_backend='disk',
        key=f'img_{domain_b}',
        flag='color'),
    dict(
        type='Resize',
        keys=[f'img_{domain_a}', f'img_{domain_b}'],
        scale=(256, 368),
        interpolation='bicubic'),
    dict(type='RescaleToZeroOne', keys=[f'img_{domain_a}', f'img_{domain_b}']),
    dict(
        type='Normalize',
        keys=[f'img_{domain_a}', f'img_{domain_b}'],
        to_rgb=False,
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]),
    dict(type='ImageToTensor', keys=[f'img_{domain_a}', f'img_{domain_b}']),
    dict(
        type='Collect',
        keys=[f'img_{domain_a}', f'img_{domain_b}'],
        meta_keys=[f'img_{domain_a}_path', f'img_{domain_b}_path'])
]

data = dict(
    train=dict(
        dataroot=dataroot,
        pipeline=train_pipeline,
        domain_a=domain_a,
        domain_b=domain_b),
    val=dict(
        dataroot=dataroot,
        domain_a=domain_a,
        domain_b=domain_b,
        pipeline=test_pipeline),
    test=dict(
        dataroot=dataroot,
        domain_a=domain_a,
        domain_b=domain_b,
        pipeline=test_pipeline))

optimizer = dict(
    generators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)),
    discriminators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)))

# learning policy
lr_config = dict(
    policy='Linear', by_epoch=False, target_lr=0, start=125000, interval=1250)

checkpoint_config = dict(interval=5000, save_optimizer=True, by_epoch=False)
custom_hooks = [
    dict(
        type='MMGenVisualizationHook',
        output_dir='training_samples',
        res_name_list=[f'fake_{domain_a}', f'fake_{domain_b}'],
        interval=5000)
]

runner = None
use_ddp_wrapper = True
total_iters = 250000
load_from = '../cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth'
# resume_from = './work_dirs/cyclegan_bw2cl/ckpt/cyclegan_bw2cl/iter_55000.pth'
workflow = [('train', 1)]
exp_name = 'cyclegan_bw2cl'
work_dir = f'./work_dirs/{exp_name}'
# testA: 716, testB:716
num_images = 716
metrics = dict(
    FID=dict(type='FID', num_images=num_images, image_shape=(3, 368, 256)),
    IS=dict(
        type='IS',
        num_images=num_images,
        image_shape=(3, 368, 256),
        inception_args=dict(type='pytorch')))

evaluation = dict(
    type='TranslationEvalHook',
    target_domain=domain_b,
    interval=5000,
    metrics=[
        dict(type='FID', num_images=num_images, bgr2rgb=True),
        dict(
            type='IS',
            num_images=num_images,
            inception_args=dict(type='pytorch'))
    ],
    best_metric=['fid', 'is'])
# Out:
# Overwriting configs/cyclegan/cyclegan_lsgan_resnet_in_summer2winter_b1x1_250k.py

# %%
# !python tools/train.py configs/cyclegan/cyclegan_lsgan_resnet_in_summer2winter_b1x1_250k.py --work-dir ./work_dirs/cyclegan_bw2cl --no-validate
# Out:
# /Users/leo/anaconda3/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /Users/leo/anaconda3/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/leo/anaconda3/lib/python3.11/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <CFED5F8E-EC3F-36FD-AAA3-2C6C7F8D3DD9> /Users/leo/anaconda3/lib/python3.11/site-packages/torchvision/image.so
#   Expected in:     <E6933B13-F4A0-3821-8466-03F22A3B3739> /Users/leo/anaconda3/lib/python3.11/site-packages/torch/lib/libtorch_cpu.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /Users/leo/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:485: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /Users/leo/Desktop/Manga-Colorization/Manga_CycleGAN/mmgeneration/tools/train.py:97: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /Users/leo/Desktop/Manga-Colorization/Manga_CycleGAN/mmgeneration/tools/train.py:107: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# 2024-04-26 15:15:37,408 - mmgen - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: darwin
# Python: 3.11.7 | packaged by conda-forge | (main, Dec 23 2023, 14:38:07) [Clang 16.0.6 ]
# CUDA available: False
# GCC: Apple clang version 15.0.0 (clang-1500.3.9.4)
# PyTorch: 2.3.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 4.2
#   - C++ Version: 201703
#   - clang 14.0.3
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: NO AVX
#   - Build settings: BLAS_INFO=accelerate, BUILD_TYPE=Release, CXX_COMPILER=/Applications/Xcode_14.3.1.app/Contents/Developer/Toolchains/XcodeDefault.xctoolchain/usr/bin/clang++, CXX_FLAGS= -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DUSE_PYTORCH_METAL_EXPORT -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DUSE_COREML_DELEGATE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=braced-scalar-init -Werror=range-loop-construct -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wvla-extension -Wsuggest-override -Wnewline-eof -Winconsistent-missing-override -Winconsistent-missing-destructor-override -Wno-pass-failed -Wno-error=pedantic -Wno-error=old-style-cast -Wno-error=inconsistent-missing-override -Wno-error=inconsistent-missing-destructor-override -Wconstant-conversion -Wno-invalid-partial-specialization -Wno-missing-braces -Qunused-arguments -fcolor-diagnostics -faligned-new -Wno-unused-but-set-variable -fno-math-errno -fno-trapping-math -Werror=format -DUSE_MPS -Wno-unused-private-field -Wno-missing-braces, LAPACK_INFO=accelerate, TORCH_VERSION=2.3.0, USE_CUDA=0, USE_CUDNN=OFF, USE_CUSPARSELT=OFF, USE_EIGEN_FOR_BLAS=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=OFF, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=ON, USE_OPENMP=OFF, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
# TorchVision: 0.15.2a0
# OpenCV: 4.6.0
# MMCV: 1.7.2
# MMGen: 0.7.3+ccd1f56
# MMCV Compiler: clang 15.0.0
# MMCV CUDA Compiler: not available
# ------------------------------------------------------------
#
# 2024-04-26 15:15:37,691 - mmgen - INFO - Distributed training: False
# 2024-04-26 15:15:37,972 - mmgen - INFO - Config:
# _domain_a = None
# _domain_b = None
# model = dict(
#     type='CycleGAN',
#     generator=dict(
#         type='ResnetGenerator',
#         in_channels=3,
#         out_channels=3,
#         base_channels=64,
#         norm_cfg=dict(type='IN'),
#         use_dropout=False,
#         num_blocks=9,
#         padding_mode='reflect',
#         init_cfg=dict(type='normal', gain=0.02)),
#     discriminator=dict(
#         type='PatchDiscriminator',
#         in_channels=3,
#         base_channels=64,
#         num_conv=3,
#         norm_cfg=dict(type='IN'),
#         init_cfg=dict(type='normal', gain=0.02)),
#     gan_loss=dict(
#         type='GANLoss',
#         gan_type='lsgan',
#         real_label_val=1.0,
#         fake_label_val=0.0,
#         loss_weight=1.0),
#     default_domain='colored',
#     reachable_domains=['grayscale', 'colored'],
#     related_domains=['grayscale', 'colored'],
#     gen_auxiliary_loss=[
#         dict(
#             type='L1Loss',
#             loss_weight=10.0,
#             loss_name='cycle_loss',
#             data_info=dict(pred='cycle_grayscale', target='real_grayscale'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=10.0,
#             loss_name='cycle_loss',
#             data_info=dict(pred='cycle_colored', target='real_colored'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=0.5,
#             loss_name='id_loss',
#             data_info=dict(pred='identity_grayscale', target='real_grayscale'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=0.5,
#             loss_name='id_loss',
#             data_info=dict(pred='identity_colored', target='real_colored'),
#             reduction='mean')
#     ])
# train_cfg = dict(buffer_size=50)
# test_cfg = None
# train_dataset_type = 'UnpairedImageDataset'
# val_dataset_type = 'UnpairedImageDataset'
# img_norm_cfg = dict(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
# domain_a = 'grayscale'
# domain_b = 'colored'
# train_pipeline = [
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_grayscale',
#         flag='color'),
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_colored',
#         flag='color'),
#     dict(
#         type='Resize',
#         keys=['img_grayscale', 'img_colored'],
#         scale=(256, 368),
#         interpolation='bicubic'),
#     dict(
#         type='Crop',
#         keys=['img_grayscale', 'img_colored'],
#         crop_size=(368, 256),
#         random_crop=True),
#     dict(type='Flip', keys=['img_grayscale'], direction='horizontal'),
#     dict(type='Flip', keys=['img_colored'], direction='horizontal'),
#     dict(type='RescaleToZeroOne', keys=['img_grayscale', 'img_colored']),
#     dict(
#         type='Normalize',
#         keys=['img_grayscale', 'img_colored'],
#         to_rgb=False,
#         mean=[0.5, 0.5, 0.5],
#         std=[0.5, 0.5, 0.5]),
#     dict(type='ImageToTensor', keys=['img_grayscale', 'img_colored']),
#     dict(
#         type='Collect',
#         keys=['img_grayscale', 'img_colored'],
#         meta_keys=['img_grayscale_path', 'img_colored_path'])
# ]
# test_pipeline = [
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_grayscale',
#         flag='color'),
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_colored',
#         flag='color'),
#     dict(
#         type='Resize',
#         keys=['img_grayscale', 'img_colored'],
#         scale=(256, 368),
#         interpolation='bicubic'),
#     dict(type='RescaleToZeroOne', keys=['img_grayscale', 'img_colored']),
#     dict(
#         type='Normalize',
#         keys=['img_grayscale', 'img_colored'],
#         to_rgb=False,
#         mean=[0.5, 0.5, 0.5],
#         std=[0.5, 0.5, 0.5]),
#     dict(type='ImageToTensor', keys=['img_grayscale', 'img_colored']),
#     dict(
#         type='Collect',
#         keys=['img_grayscale', 'img_colored'],
#         meta_keys=['img_grayscale_path', 'img_colored_path'])
# ]
# data_root = None
# data = dict(
#     samples_per_gpu=1,
#     workers_per_gpu=4,
#     drop_last=True,
#     train=dict(
#         type='UnpairedImageDataset',
#         dataroot=
#         '/Users/leo/Desktop/Manga-Colorization/manga_dataset/train_test/',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_grayscale',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_colored',
#                 flag='color'),
#             dict(
#                 type='Resize',
#                 keys=['img_grayscale', 'img_colored'],
#                 scale=(256, 368),
#                 interpolation='bicubic'),
#             dict(
#                 type='Crop',
#                 keys=['img_grayscale', 'img_colored'],
#                 crop_size=(368, 256),
#                 random_crop=True),
#             dict(type='Flip', keys=['img_grayscale'], direction='horizontal'),
#             dict(type='Flip', keys=['img_colored'], direction='horizontal'),
#             dict(
#                 type='RescaleToZeroOne', keys=['img_grayscale',
#                                                'img_colored']),
#             dict(
#                 type='Normalize',
#                 keys=['img_grayscale', 'img_colored'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_grayscale', 'img_colored']),
#             dict(
#                 type='Collect',
#                 keys=['img_grayscale', 'img_colored'],
#                 meta_keys=['img_grayscale_path', 'img_colored_path'])
#         ],
#         test_mode=False,
#         domain_a='grayscale',
#         domain_b='colored'),
#     val=dict(
#         type='UnpairedImageDataset',
#         dataroot=
#         '/Users/leo/Desktop/Manga-Colorization/manga_dataset/train_test/',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_grayscale',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_colored',
#                 flag='color'),
#             dict(
#                 type='Resize',
#                 keys=['img_grayscale', 'img_colored'],
#                 scale=(256, 368),
#                 interpolation='bicubic'),
#             dict(
#                 type='RescaleToZeroOne', keys=['img_grayscale',
#                                                'img_colored']),
#             dict(
#                 type='Normalize',
#                 keys=['img_grayscale', 'img_colored'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_grayscale', 'img_colored']),
#             dict(
#                 type='Collect',
#                 keys=['img_grayscale', 'img_colored'],
#                 meta_keys=['img_grayscale_path', 'img_colored_path'])
#         ],
#         test_mode=True,
#         domain_a='grayscale',
#         domain_b='colored'),
#     test=dict(
#         type='UnpairedImageDataset',
#         dataroot=
#         '/Users/leo/Desktop/Manga-Colorization/manga_dataset/train_test/',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_grayscale',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_colored',
#                 flag='color'),
#             dict(
#                 type='Resize',
#                 keys=['img_grayscale', 'img_colored'],
#                 scale=(256, 368),
#                 interpolation='bicubic'),
#             dict(
#                 type='RescaleToZeroOne', keys=['img_grayscale',
#                                                'img_colored']),
#             dict(
#                 type='Normalize',
#                 keys=['img_grayscale', 'img_colored'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_grayscale', 'img_colored']),
#             dict(
#                 type='Collect',
#                 keys=['img_grayscale', 'img_colored'],
#                 meta_keys=['img_grayscale_path', 'img_colored_path'])
#         ],
#         test_mode=True,
#         domain_a='grayscale',
#         domain_b='colored'))
# checkpoint_config = dict(interval=5000, by_epoch=False, save_optimizer=True)
# log_config = dict(interval=100, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [
#     dict(
#         type='MMGenVisualizationHook',
#         output_dir='training_samples',
#         res_name_list=['fake_grayscale', 'fake_colored'],
#         interval=5000)
# ]
# runner = None
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = '../cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth'
# resume_from = None
# workflow = [('train', 1)]
# find_unused_parameters = True
# cudnn_benchmark = True
# opencv_num_threads = 0
# mp_start_method = 'fork'
# dataroot = '/Users/leo/Desktop/Manga-Colorization/manga_dataset/train_test/'
# optimizer = dict(
#     generators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)),
#     discriminators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)))
# lr_config = dict(
#     policy='Linear', by_epoch=False, target_lr=0, start=125000, interval=1250)
# use_ddp_wrapper = True
# total_iters = 250000
# exp_name = 'cyclegan_bw2cl'
# work_dir = './work_dirs/cyclegan_bw2cl'
# num_images = 716
# metrics = dict(
#     FID=dict(type='FID', num_images=716, image_shape=(3, 368, 256)),
#     IS=dict(
#         type='IS',
#         num_images=716,
#         image_shape=(3, 368, 256),
#         inception_args=dict(type='pytorch')))
# evaluation = dict(
#     type='TranslationEvalHook',
#     target_domain='colored',
#     interval=5000,
#     metrics=[
#         dict(type='FID', num_images=716, bgr2rgb=True),
#         dict(type='IS', num_images=716, inception_args=dict(type='pytorch'))
#     ],
#     best_metric=['fid', 'is'])
# gpu_ids = [0]
#
# 2024-04-26 15:15:37,974 - mmgen - INFO - Set random seed to 2021, deterministic: False, use_rank_shift: False
# /Users/leo/anaconda3/lib/python3.11/site-packages/mmcv/cnn/bricks/conv_module.py:153: UserWarning: Unnecessary conv bias before batch/instance norm
#   warnings.warn(
# 2024-04-26 15:15:38,808 - mmgen - INFO - load checkpoint from local path: ../cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth
# 2024-04-26 15:15:38,864 - mmgen - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: generators.winter.model.0.conv.weight, generators.winter.model.0.conv.bias, generators.winter.model.1.conv.weight, generators.winter.model.1.conv.bias, generators.winter.model.2.conv.weight, generators.winter.model.2.conv.bias, generators.winter.model.3.block.0.conv.weight, generators.winter.model.3.block.0.conv.bias, generators.winter.model.3.block.1.conv.weight, generators.winter.model.3.block.1.conv.bias, generators.winter.model.4.block.0.conv.weight, generators.winter.model.4.block.0.conv.bias, generators.winter.model.4.block.1.conv.weight, generators.winter.model.4.block.1.conv.bias, generators.winter.model.5.block.0.conv.weight, generators.winter.model.5.block.0.conv.bias, generators.winter.model.5.block.1.conv.weight, generators.winter.model.5.block.1.conv.bias, generators.winter.model.6.block.0.conv.weight, generators.winter.model.6.block.0.conv.bias, generators.winter.model.6.block.1.conv.weight, generators.winter.model.6.block.1.conv.bias, generators.winter.model.7.block.0.conv.weight, generators.winter.model.7.block.0.conv.bias, generators.winter.model.7.block.1.conv.weight, generators.winter.model.7.block.1.conv.bias, generators.winter.model.8.block.0.conv.weight, generators.winter.model.8.block.0.conv.bias, generators.winter.model.8.block.1.conv.weight, generators.winter.model.8.block.1.conv.bias, generators.winter.model.9.block.0.conv.weight, generators.winter.model.9.block.0.conv.bias, generators.winter.model.9.block.1.conv.weight, generators.winter.model.9.block.1.conv.bias, generators.winter.model.10.block.0.conv.weight, generators.winter.model.10.block.0.conv.bias, generators.winter.model.10.block.1.conv.weight, generators.winter.model.10.block.1.conv.bias, generators.winter.model.11.block.0.conv.weight, generators.winter.model.11.block.0.conv.bias, generators.winter.model.11.block.1.conv.weight, generators.winter.model.11.block.1.conv.bias, generators.winter.model.12.conv.weight, generators.winter.model.12.conv.bias, generators.winter.model.13.conv.weight, generators.winter.model.13.conv.bias, generators.winter.model.14.conv.weight, generators.winter.model.14.conv.bias, generators.summer.model.0.conv.weight, generators.summer.model.0.conv.bias, generators.summer.model.1.conv.weight, generators.summer.model.1.conv.bias, generators.summer.model.2.conv.weight, generators.summer.model.2.conv.bias, generators.summer.model.3.block.0.conv.weight, generators.summer.model.3.block.0.conv.bias, generators.summer.model.3.block.1.conv.weight, generators.summer.model.3.block.1.conv.bias, generators.summer.model.4.block.0.conv.weight, generators.summer.model.4.block.0.conv.bias, generators.summer.model.4.block.1.conv.weight, generators.summer.model.4.block.1.conv.bias, generators.summer.model.5.block.0.conv.weight, generators.summer.model.5.block.0.conv.bias, generators.summer.model.5.block.1.conv.weight, generators.summer.model.5.block.1.conv.bias, generators.summer.model.6.block.0.conv.weight, generators.summer.model.6.block.0.conv.bias, generators.summer.model.6.block.1.conv.weight, generators.summer.model.6.block.1.conv.bias, generators.summer.model.7.block.0.conv.weight, generators.summer.model.7.block.0.conv.bias, generators.summer.model.7.block.1.conv.weight, generators.summer.model.7.block.1.conv.bias, generators.summer.model.8.block.0.conv.weight, generators.summer.model.8.block.0.conv.bias, generators.summer.model.8.block.1.conv.weight, generators.summer.model.8.block.1.conv.bias, generators.summer.model.9.block.0.conv.weight, generators.summer.model.9.block.0.conv.bias, generators.summer.model.9.block.1.conv.weight, generators.summer.model.9.block.1.conv.bias, generators.summer.model.10.block.0.conv.weight, generators.summer.model.10.block.0.conv.bias, generators.summer.model.10.block.1.conv.weight, generators.summer.model.10.block.1.conv.bias, generators.summer.model.11.block.0.conv.weight, generators.summer.model.11.block.0.conv.bias, generators.summer.model.11.block.1.conv ...
#
# missing keys in source state_dict: generators.grayscale.model.0.conv.weight, generators.grayscale.model.0.conv.bias, generators.grayscale.model.1.conv.weight, generators.grayscale.model.1.conv.bias, generators.grayscale.model.2.conv.weight, generators.grayscale.model.2.conv.bias, generators.grayscale.model.3.block.0.conv.weight, generators.grayscale.model.3.block.0.conv.bias, generators.grayscale.model.3.block.1.conv.weight, generators.grayscale.model.3.block.1.conv.bias, generators.grayscale.model.4.block.0.conv.weight, generators.grayscale.model.4.block.0.conv.bias, generators.grayscale.model.4.block.1.conv.weight, generators.grayscale.model.4.block.1.conv.bias, generators.grayscale.model.5.block.0.conv.weight, generators.grayscale.model.5.block.0.conv.bias, generators.grayscale.model.5.block.1.conv.weight, generators.grayscale.model.5.block.1.conv.bias, generators.grayscale.model.6.block.0.conv.weight, generators.grayscale.model.6.block.0.conv.bias, generators.grayscale.model.6.block.1.conv.weight, generators.grayscale.model.6.block.1.conv.bias, generators.grayscale.model.7.block.0.conv.weight, generators.grayscale.model.7.block.0.conv.bias, generators.grayscale.model.7.block.1.conv.weight, generators.grayscale.model.7.block.1.conv.bias, generators.grayscale.model.8.block.0.conv.weight, generators.grayscale.model.8.block.0.conv.bias, generators.grayscale.model.8.block.1.conv.weight, generators.grayscale.model.8.block.1.conv.bias, generators.grayscale.model.9.block.0.conv.weight, generators.grayscale.model.9.block.0.conv.bias, generators.grayscale.model.9.block.1.conv.weight, generators.grayscale.model.9.block.1.conv.bias, generators.grayscale.model.10.block.0.conv.weight, generators.grayscale.model.10.block.0.conv.bias, generators.grayscale.model.10.block.1.conv.weight, generators.grayscale.model.10.block.1.conv.bias, generators.grayscale.model.11.block.0.conv.weight, generators.grayscale.model.11.block.0.conv.bias, generators.grayscale.model.11.block.1.conv.weight, generators.grayscale.model.11.block.1.conv.bias, generators.grayscale.model.12.conv.weight, generators.grayscale.model.12.conv.bias, generators.grayscale.model.13.conv.weight, generators.grayscale.model.13.conv.bias, generators.grayscale.model.14.conv.weight, generators.grayscale.model.14.conv.bias, generators.colored.model.0.conv.weight, generators.colored.model.0.conv.bias, generators.colored.model.1.conv.weight, generators.colored.model.1.conv.bias, generators.colored.model.2.conv.weight, generators.colored.model.2.conv.bias, generators.colored.model.3.block.0.conv.weight, generators.colored.model.3.block.0.conv.bias, generators.colored.model.3.block.1.conv.weight, generators.colored.model.3.block.1.conv.bias, generators.colored.model.4.block.0.conv.weight, generators.colored.model.4.block.0.conv.bias, generators.colored.model.4.block.1.conv.weight, generators.colored.model.4.block.1.conv.bias, generators.colored.model.5.block.0.conv.weight, generators.colored.model.5.block.0.conv.bias, generators.colored.model.5.block.1.conv.weight, generators.colored.model.5.block.1.conv.bias, generators.colored.model.6.block.0.conv.weight, generators.colored.model.6.block.0.conv.bias, generators.colored.model.6.block.1.conv.weight, generators.colored.model.6.block.1.conv.bias, generators.colored.model.7.block.0.conv.weight, generators.colored.model.7.block.0.conv.bias, generators.colored.model.7.block.1.conv.weight, generators.colored.model.7.block.1.conv.bias, generators.colored.model.8.block.0.conv.weight, generators.colored.model.8.block.0.conv.bias, generators.colored.model.8.block.1.conv.weight, generators.colored.model.8.block.1.conv.bias, generators.colored.model.9.block.0.conv.weight, generators.colored.model.9.block.0.conv.bias, generators.colored.model.9.block.1.conv.weight, generators.colored.model.9.block.1.conv.bias, generators.colored.model.10.block.0.conv.weight, generators.colored.model.10.block.0.conv.bias, generators.colored.model.10.block.1.conv.weight,  ...
#
# 2024-04-26 15:15:38,869 - mmgen - INFO - Start running, host: leo@MacBook-Air-4.lan, work_dir: /Users/leo/Desktop/Manga-Colorization/Manga_CycleGAN/mmgeneration/work_dirs/cyclegan_bw2cl
# 2024-04-26 15:15:38,869 - mmgen - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) VisualizationHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2024-04-26 15:15:38,869 - mmgen - INFO - workflow: [('train', 1)], max: 250000 iters
# 2024-04-26 15:15:38,869 - mmgen - INFO - Checkpoints will be saved to ./work_dirs/cyclegan_bw2cl/ckpt/cyclegan_bw2cl by HardDiskBackend.
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# 2024-04-26 15:37:53,988 - mmgen - INFO - Iter [100/250000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 38 days, 14:46:35, time: 13.351, data_time: 0.004, loss_gan_d_grayscale: 0.8300, loss_gan_d_colored: 0.9267, loss_gan_g_grayscale: 1.0460, loss_gan_g_colored: 1.3688, cycle_loss: 10.1100, id_loss: 0.5140, loss: 13.0388
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# ^C

# %%
import os

# %%
len(os.listdir('/Users/leo/Desktop/Manga-Colorization/training_samples'))
# Out:
# 32

# %%
len(os.listdir('/Users/leo/Desktop/Manga-Colorization/weight'))
# Out:
# 31
