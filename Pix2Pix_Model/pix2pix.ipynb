# %% [markdown]
# <a href="https://colab.research.google.com/github/bkkaggle/pytorch-CycleGAN-and-pix2pix/blob/master/pix2pix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Datasets
#
# Download one of the official datasets with:
#
# -   `bash ./datasets/download_pix2pix_dataset.sh [cityscapes, night2day, edges2handbags, edges2shoes, facades, maps]`
#
# Or use your own dataset by creating the appropriate folders and adding in the images. Follow the instructions [here](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/docs/datasets.md#pix2pix-datasets).

# %%
# !bash ./datasets/download_pix2pix_dataset.sh facades

# %% [markdown]
# # Pretrained models
#
# Download one of the official pretrained models with:
#
# -   `bash ./scripts/download_pix2pix_model.sh [edges2shoes, sat2map, map2sat, facades_label2photo, and day2night]`
#
# Or add your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
# !bash ./scripts/download_pix2pix_model.sh facades_label2photo

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/facades --name facades_pix2pix --model pix2pix --direction BtoA`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. Add `--direction BtoA` if you want to train a model to transfrom from class B to A.

# %%
# !python train.py --dataroot ./datasets/facades --name facades_pix2pix --model pix2pix --direction BtoA --display_id -1

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot ./datasets/facades --direction BtoA --model pix2pix --name facades_pix2pix`
#
# Change the `--dataroot`, `--name`, and `--direction` to be consistent with your trained model's configuration and how you want to transform images.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > Note that we specified --direction BtoA as Facades dataset's A to B direction is photos to labels.
#
# > If you would like to apply a pre-trained model to a collection of input images (rather than image pairs), please use --model test option. See ./scripts/test_single.sh for how to apply a model to Facade label maps (stored in the directory facades/testB).
#
# > See a list of currently available models at ./scripts/download_pix2pix_model.sh

# %%
# !ls checkpoints/

# %%
# !python test.py --dataroot ./datasets/facades --direction BtoA --model pix2pix --name facades_label2photo_pretrained --use_wandb

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/100_fake_B.png')
plt.imshow(img)

# %%
img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/100_real_A.png')
plt.imshow(img)

# %%
img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/100_real_B.png')
plt.imshow(img)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
# Define the image path
image_path = '/Users/leo/Desktop/Manga-Colorization/pix2pix_baseline_results/fakeB/bukonohero_cl359.png'

# Open the image
image = Image.open(image_path)

# Display the image using matplotlib
plt.imshow(image)
plt.title('Image')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 image_path = '/Users/leo/Desktop/Manga-Colorization/pix2pix_baseline_results/fakeB/bukonohero_cl359.png'
#       7 # Open the image
# ----> 8 image = Image.open(image_path)
#      10 # Display the image using matplotlib
#      11 plt.imshow(image)
#
# File ~/Library/Python/3.9/lib/python/site-packages/PIL/Image.py:3243, in open(fp, mode, formats)
#    3240     filename = fp
#    3242 if filename:
# -> 3243     fp = builtins.open(filename, "rb")
#    3244     exclusive_fp = True
#    3246 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/leo/Desktop/Manga-Colorization/pix2pix_baseline_results/fakeB/bukonohero_cl359.png'

# %%
# Out:
# ['bukonohero_cl359.png',
#  'blackclover_cl987.png',
#  'onepiece_cl489.png',
#  'bukonohero_cl629.png',
#  'blackclover_cl561.png',
#  'bukonohero_cl615.png',
#  'onepiece_cl660.png',
#  'bukonohero_cl173.png',
#  'bukonohero_cl167.png',
#  'blackclover_cl401.png',
#  'onepiece_cl1394.png',
#  'bukonohero_cl775.png',
#  'onepiece_cl933.png',
#  'bukonohero_cl1048.png',
#  'onepiece_cl1425.png',
#  'blackclover_cl1043.png',
#  'bukonohero_cl239.png',
#  'blackclover_cl1057.png',
#  'onepiece_cl1182.png',
#  'onepiece_cl1169.png',
#  'bukonohero_cl588.png',
#  'bukonohero_cl562.png',
#  'onepiece_cl259.png',
#  'onepiece_cl1430.png',
#  'bukonohero_cl1049.png',
#  'onepiece_cl926.png',
#  'onepiece_cl1381.png',
#  'blackclover_cl414.png',
#  'onepiece_cl729.png',
#  'onepiece_cl852.png',
#  'bukonohero_cl199.png',
#  'bukonohero_cl827.png',
#  'onepiece_cl661.png',
#  'blackclover_cl574.png',
#  'onepiece_cl1034.png',
#  'onepiece_cl477.png',
#  'bukonohero_cl416.png',
#  'onepiece_cl475.png',
#  'bukonohero_cl366.png',
#  'bukonohero_cl400.png',
#  'onepiece_cl1022.png',
#  'blackclover_cl576.png',
#  'bukonohero_cl164.png',
#  'onepiece_cl677.png',
#  'onepiece_cl105.png',
#  'onepiece_cl688.png',
#  'onepiece_cl844.png',
#  'bukonohero_cl37.png',
#  'blackclover_cl416.png',
#  'blackclover_cl364.png',
#  'bukonohero_cl986.png',
#  'bukonohero_cl776.png',
#  'onepiece_cl23.png',
#  'bukonohero_cl951.png',
#  'onepiece_cl918.png',
#  'bukonohero_cl979.png',
#  'blackclover_cl172.png',
#  'onepiece_cl1181.png',
#  'onepiece_cl1142.png',
#  'blackclover_cl199.png',
#  'onepiece_cl1157.png',
#  'blackclover_cl198.png',
#  'blackclover_cl832.png',
#  'bukonohero_cl207.png',
#  'bukonohero_cl575.png',
#  'blackclover_cl601.png',
#  'blackclover_cl1055.png',
#  'blackclover_cl615.png',
#  'onepiece_cl1427.png',
#  'onepiece_cl36.png',
#  'bukonohero_cl950.png',
#  'onepiece_cl702.png',
#  'onepiece_cl879.png',
#  'onepiece_cl1221.png',
#  'blackclover_cl588.png',
#  'onepiece_cl1235.png',
#  'bukonohero_cl617.png',
#  'onepiece_cl676.png',
#  'blackclover_cl211.png',
#  'onepiece_cl138.png',
#  'bukonohero_cl159.png',
#  'bukonohero_cl367.png',
#  'onepiece_cl312.png',
#  'blackclover_cl761.png',
#  'bukonohero_cl377.png',
#  'bukonohero_cl439.png',
#  'onepiece_cl1033.png',
#  'bukonohero_cl388.png',
#  'bukonohero_cl161.png',
#  'onepiece_cl114.png',
#  'bukonohero_cl607.png',
#  'onepiece_cl666.png',
#  'onepiece_cl896.png',
#  'blackclover_cl573.png',
#  'onepiece_cl869.png',
#  'onepiece_cl1231.png',
#  'onepiece_cl706.png',
#  'bukonohero_cl773.png',
#  'onepiece_cl712.png',
#  'blackclover_cl413.png',
#  'onepiece_cl1345.png',
#  'onepiece_cl1351.png',
#  'onepiece_cl26.png',
#  'onepiece_cl935.png',
#  'bukonohero_cl571.png',
#  'onepiece_cl510.png',
#  'onepiece_cl1190.png',
#  'blackclover_cl611.png',
#  'onepiece_cl538.png',
#  'onepiece_cl1147.png',
#  'blackclover_cl822.png',
#  'onepiece_cl1153.png',
#  'onepiece_cl288.png',
#  'onepiece_cl1146.png',
#  'onepiece_cl1191.png',
#  'bukonohero_cl799.png',
#  'blackclover_cl406.png',
#  'blackclover_cl374.png',
#  'onepiece_cl707.png',
#  'onepiece_cl868.png',
#  'onepiece_cl129.png',
#  'blackclover_cl566.png',
#  'onepiece_cl101.png',
#  'bukonohero_cl612.png',
#  'bukonohero_cl160.png',
#  'onepiece_cl115.png',
#  'blackclover_cl14.png',
#  'onepiece_cl459.png',
#  'bukonohero_cl410.png',
#  'onepiece_cl471.png',
#  'onepiece_cl301.png',
#  'blackclover_cl996.png',
#  'blackclover_cl16.png',
#  'bukonohero_cl176.png',
#  'blackclover_cl558.png',
#  'onepiece_cl881.png',
#  'blackclover_cl570.png',
#  'bukonohero_cl25.png',
#  'bukonohero_cl31.png',
#  'onepiece_cl1232.png',
#  'onepiece_cl842.png',
#  'onepiece_cl1434.png',
#  'onepiece_cl1346.png',
#  'onepiece_cl31.png',
#  'onepiece_cl25.png',
#  'bukonohero_cl957.png',
#  'bukonohero_cl599.png',
#  'onepiece_cl1178.png',
#  'blackclover_cl175.png',
#  'blackclover_cl161.png',
#  'bukonohero_cl215.png',
#  'blackclover_cl149.png',
#  'bukonohero_cl956.png',
#  'onepiece_cl1409.png',
#  'onepiece_cl1347.png',
#  'onepiece_cl1421.png',
#  'blackclover_cl377.png',
#  'bukonohero_cl981.png',
#  'onepiece_cl1384.png',
#  'onepiece_cl710.png',
#  'onepiece_cl1390.png',
#  'bukonohero_cl188.png',
#  'blackclover_cl565.png',
#  'onepiece_cl894.png',
#  'blackclover_cl203.png',
#  'onepiece_cl658.png',
#  'blackclover_cl571.png',
#  'bukonohero_cl605.png',
#  'onepiece_cl116.png',
#  'bukonohero_cl163.png',
#  'blackclover_cl968.png',
#  'blackclover_cl798.png',
#  'bukonohero_cl413.png',
#  'blackclover_cl728.png',
#  'bukonohero_cl306.png',
#  'onepiece_cl1095.png',
#  'bukonohero_cl460.png',
#  'onepiece_cl398.png',
#  'onepiece_cl1042.png',
#  'blackclover_cl58.png',
#  'onepiece_cl159.png',
#  'blackclover_cl264.png',
#  'onepiece_cl603.png',
#  'bukonohero_cl662.png',
#  'bukonohero_cl94.png',
#  'bukonohero_cl851.png',
#  'bukonohero_cl845.png',
#  'bukonohero_cl43.png',
#  'bukonohero_cl879.png',
#  'onepiece_cl777.png',
#  'bukonohero_cl716.png',
#  'onepiece_cl788.png',
#  'onepiece_cl1308.png',
#  'bukonohero_cl1003.png',
#  'onepiece_cl1452.png',
#  'onepiece_cl1334.png',
#  'blackclover_cl660.png',
#  'bukonohero_cl500.png',
#  'blackclover_cl1008.png',
#  'blackclover_cl648.png',
#  'onepiece_cl1123.png',
#  'onepiece_cl206.png',
#  'onepiece_cl212.png',
#  'blackclover_cl885.png',
#  'bukonohero_cl267.png',
#  'onepiece_cl574.png',
#  'blackclover_cl113.png',
#  'bukonohero_cl529.png',
#  'onepiece_cl548.png',
#  'onepiece_cl42.png',
#  'onepiece_cl56.png',
#  'onepiece_cl1309.png',
#  'bukonohero_cl56.png',
#  'onepiece_cl819.png',
#  'bukonohero_cl688.png',
#  'bukonohero_cl850.png',
#  'onepiece_cl1296.png',
#  'bukonohero_cl111.png',
#  'bukonohero_cl887.png',
#  'bukonohero_cl139.png',
#  'blackclover_cl65.png',
#  'blackclover_cl71.png',
#  'onepiece_cl414.png',
#  'onepiece_cl400.png',
#  'blackclover_cl98.png',
#  'bukonohero_cl463.png',
#  'onepiece_cl416.png',
#  'bukonohero_cl477.png',
#  'blackclover_cl73.png',
#  'bukonohero_cl107.png',
#  'bukonohero_cl83.png',
#  'onepiece_cl166.png',
#  'bukonohero_cl113.png',
#  'onepiece_cl600.png',
#  'bukonohero_cl852.png',
#  'blackclover_cl298.png',
#  'onepiece_cl1257.png',
#  'bukonohero_cl40.png',
#  'onepiece_cl1243.png',
#  'bukonohero_cl729.png',
#  'blackclover_cl461.png',
#  'bukonohero_cl715.png',
#  'onepiece_cl1323.png',
#  'onepiece_cl238.png',
#  'onepiece_cl210.png',
#  'onepiece_cl1109.png',
#  'blackclover_cl844.png',
#  'onepiece_cl1134.png',
#  'blackclover_cl851.png',
#  'onepiece_cl588.png',
#  'blackclover_cl879.png',
#  'bukonohero_cl502.png',
#  'blackclover_cl676.png',
#  'onepiece_cl55.png',
#  'bukonohero_cl41.png',
#  'onepiece_cl1256.png',
#  'blackclover_cl528.png',
#  'onepiece_cl1281.png',
#  'bukonohero_cl106.png',
#  'blackclover_cl500.png',
#  'onepiece_cl3.png',
#  'blackclover_cl931.png',
#  'onepiece_cl359.png',
#  'bukonohero_cl466.png',
#  'blackclover_cl89.png',
#  'onepiece_cl407.png',
#  'onepiece_cl349.png',
#  'blackclover_cl712.png',
#  'blackclover_cl62.png',
#  'bukonohero_cl499.png',
#  'onepiece_cl1078.png',
#  'blackclover_cl909.png',
#  'onepiece_cl611.png',
#  'bukonohero_cl102.png',
#  'onepiece_cl1285.png',
#  'bukonohero_cl658.png',
#  'onepiece_cl188.png',
#  'bukonohero_cl704.png',
#  'blackclover_cl302.png',
#  'onepiece_cl1440.png',
#  'onepiece_cl956.png',
#  'onepiece_cl201.png',
#  'bukonohero_cl506.png',
#  'onepiece_cl1131.png',
#  'onepiece_cl228.png',
#  'bukonohero_cl249.png',
#  'blackclover_cl673.png',
#  'onepiece_cl200.png',
#  'bukonohero_cl711.png',
#  'blackclover_cl288.png',
#  'onepiece_cl1247.png',
#  'blackclover_cl277.png',
#  'onepiece_cl604.png',
#  'onepiece_cl162.png',
#  'onepiece_cl1284.png',
#  'bukonohero_cl93.png',
#  'bukonohero_cl665.png',
#  'onepiece_cl610.png',
#  'blackclover_cl63.png',
#  'onepiece_cl6.png',
#  'blackclover_cl920.png',
#  'onepiece_cl1086.png',
#  'bukonohero_cl467.png',
#  'onepiece_cl1092.png',
#  'onepiece_cl374.png',
#  'onepiece_cl376.png',
#  'bukonohero_cl465.png',
#  'onepiece_cl438.png',
#  'onepiece_cl389.png',
#  'blackclover_cl249.png',
#  'bukonohero_cl91.png',
#  'onepiece_cl174.png',
#  'blackclover_cl261.png',
#  'blackclover_cl507.png',
#  'bukonohero_cl883.png',
#  'bukonohero_cl854.png',
#  'bukonohero_cl840.png',
#  'onepiece_cl996.png',
#  'bukonohero_cl1012.png',
#  'onepiece_cl955.png',
#  'bukonohero_cl934.png',
#  'onepiece_cl570.png',
#  'blackclover_cl659.png',
#  'blackclover_cl1025.png',
#  'blackclover_cl671.png',
#  'bukonohero_cl288.png',
#  'blackclover_cl102.png',
#  'onepiece_cl203.png',
#  'onepiece_cl565.png',
#  'bukonohero_cl276.png',
#  'onepiece_cl571.png',
#  'blackclover_cl880.png',
#  'bukonohero_cl921.png',
#  'onepiece_cl53.png',
#  'blackclover_cl300.png',
#  'onepiece_cl767.png',
#  'bukonohero_cl699.png',
#  'onepiece_cl149.png',
#  'bukonohero_cl666.png',
#  'bukonohero_cl114.png',
#  'blackclover_cl937.png',
#  'onepiece_cl1091.png',
#  'onepiece_cl411.png',
#  'onepiece_cl408.png',
#  'onepiece_cl420.png',
#  'onepiece_cl434.png',
#  'bukonohero_cl327.png',
#  'bukonohero_cl441.png',
#  'blackclover_cl51.png',
#  'onepiece_cl1077.png',
#  'blackclover_cl79.png',
#  'blackclover_cl245.png',
#  'onepiece_cl636.png',
#  'bukonohero_cl723.png',
#  'onepiece_cl971.png',
#  'onepiece_cl959.png',
#  'blackclover_cl641.png',
#  'onepiece_cl568.png',
#  'blackclover_cl133.png',
#  'bukonohero_cl521.png',
#  'blackclover_cl696.png',
#  'bukonohero_cl291.png',
#  'blackclover_cl873.png',
#  'onepiece_cl227.png',
#  'onepiece_cl1300.png',
#  'onepiece_cl958.png',
#  'bukonohero_cl911.png',
#  'onepiece_cl63.png',
#  'blackclover_cl495.png',
#  'bukonohero_cl1023.png',
#  'bukonohero_cl1037.png',
#  'onepiece_cl970.png',
#  'blackclover_cl481.png',
#  'bukonohero_cl905.png',
#  'onepiece_cl77.png',
#  'blackclover_cl330.png',
#  'bukonohero_cl642.png',
#  'onepiece_cl145.png',
#  'bukonohero_cl656.png',
#  'bukonohero_cl88.png',
#  'blackclover_cl250.png',
#  'bukonohero_cl326.png',
#  'bukonohero_cl440.png',
#  'bukonohero_cl468.png',
#  'blackclover_cl85.png',
#  'bukonohero_cl318.png',
#  'onepiece_cl379.png',
#  'blackclover_cl939.png',
#  'blackclover_cl46.png',
#  'blackclover_cl52.png',
#  'onepiece_cl1074.png',
#  'bukonohero_cl481.png',
#  'onepiece_cl609.png',
#  'blackclover_cl520.png',
#  'blackclover_cl534.png',
#  'bukonohero_cl126.png',
#  'onepiece_cl635.png',
#  'bukonohero_cl654.png',
#  'onepiece_cl812.png',
#  'bukonohero_cl49.png',
#  'bukonohero_cl873.png',
#  'onepiece_cl190.png',
#  'onepiece_cl184.png',
#  'bukonohero_cl61.png',
#  'blackclover_cl440.png',
#  'onepiece_cl741.png',
#  'bukonohero_cl734.png',
#  'onepiece_cl61.png',
#  'blackclover_cl483.png',
#  'bukonohero_cl1035.png',
#  'blackclover_cl1002.png',
#  'blackclover_cl642.png',
#  'bukonohero_cl250.png',
#  'onepiece_cl580.png',
#  'blackclover_cl870.png',
#  'onepiece_cl581.png',
#  'blackclover_cl858.png',
#  'onepiece_cl1129.png',
#  'blackclover_cl119.png',
#  'bukonohero_cl523.png',
#  'onepiece_cl224.png',
#  'onepiece_cl542.png',
#  'bukonohero_cl906.png',
#  'bukonohero_cl1020.png',
#  'onepiece_cl998.png',
#  'blackclover_cl290.png',
#  'bukonohero_cl866.png',
#  'onepiece_cl146.png',
#  'bukonohero_cl641.png',
#  'blackclover_cl535.png',
#  'onepiece_cl1288.png',
#  'blackclover_cl47.png',
#  'onepiece_cl1049.png',
#  'bukonohero_cl325.png',
#  'onepiece_cl436.png',
#  'blackclover_cl84.png',
#  'onepiece_cl432.png',
#  'onepiece_cl426.png',
#  'bukonohero_cl0.png',
#  'bukonohero_cl309.png',
#  'onepiece_cl383.png',
#  'blackclover_cl519.png',
#  'onepiece_cl630.png',
#  'bukonohero_cl137.png',
#  'bukonohero_cl686.png',
#  'onepiece_cl195.png',
#  'bukonohero_cl70.png',
#  'onepiece_cl181.png',
#  'onepiece_cl1267.png',
#  'bukonohero_cl862.png',
#  'bukonohero_cl731.png',
#  'onepiece_cl744.png',
#  'onepiece_cl750.png',
#  'bukonohero_cl725.png',
#  'blackclover_cl445.png',
#  'blackclover_cl492.png',
#  'bukonohero_cl916.png',
#  'onepiece_cl977.png',
#  'bukonohero_cl902.png',
#  'blackclover_cl486.png',
#  'bukonohero_cl533.png',
#  'onepiece_cl234.png',
#  'blackclover_cl647.png',
#  'onepiece_cl585.png',
#  'blackclover_cl874.png',
#  'onepiece_cl1105.png',
#  'onepiece_cl591.png',
#  'blackclover_cl690.png',
#  'blackclover_cl691.png',
#  'bukonohero_cl283.png',
#  'onepiece_cl590.png',
#  'blackclover_cl875.png',
#  'blackclover_cl646.png',
#  'bukonohero_cl268.png',
#  'onepiece_cl553.png',
#  'bukonohero_cl1031.png',
#  'onepiece_cl962.png',
#  'onepiece_cl1460.png',
#  'onepiece_cl779.png',
#  'blackclover_cl336.png',
#  'onepiece_cl989.png',
#  'bukonohero_cl730.png',
#  'blackclover_cl281.png',
#  'bukonohero_cl693.png',
#  'onepiece_cl180.png',
#  'blackclover_cl256.png',
#  'onepiece_cl1299.png',
#  'onepiece_cl143.png',
#  'bukonohero_cl650.png',
#  'blackclover_cl42.png',
#  'onepiece_cl369.png',
#  'onepiece_cl341.png',
#  'bukonohero_cl320.png',
#  'onepiece_cl355.png',
#  'bukonohero_cl450.png',
#  'bukonohero_cl444.png',
#  'bukonohero_cl3.png',
#  'onepiece_cl1099.png',
#  'onepiece_cl1066.png',
#  'blackclover_cl917.png',
#  'blackclover_cl903.png',
#  'blackclover_cl40.png',
#  'onepiece_cl155.png',
#  'bukonohero_cl691.png',
#  'bukonohero_cl685.png',
#  'onepiece_cl1258.png',
#  'blackclover_cl297.png',
#  'blackclover_cl283.png',
#  'bukonohero_cl726.png',
#  'onepiece_cl1310.png',
#  'onepiece_cl948.png',
#  'bukonohero_cl1033.png',
#  'bukonohero_cl1027.png',
#  'bukonohero_cl242.png',
#  'blackclover_cl122.png',
#  'blackclover_cl1004.png',
#  'blackclover_cl1010.png',
#  'onepiece_cl1106.png',
#  'onepiece_cl544.png',
#  'onepiece_cl236.png',
#  'onepiece_cl961.png',
#  'onepiece_cl66.png',
#  'bukonohero_cl900.png',
#  'bukonohero_cl928.png',
#  'bukonohero_cl727.png',
#  'onepiece_cl829.png',
#  'onepiece_cl1271.png',
#  'onepiece_cl183.png',
#  'blackclover_cl241.png',
#  'blackclover_cl527.png',
#  'onepiece_cl632.png',
#  'bukonohero_cl653.png',
#  'bukonohero_cl135.png',
#  'onepiece_cl626.png',
#  'blackclover_cl82.png',
#  'blackclover_cl96.png',
#  'onepiece_cl356.png',
#  'onepiece_cl424.png',
#  'bukonohero_cl451.png',
#  'bukonohero_cl436.png',
#  'blackclover_cl0.png',
#  'blackclover_cl795.png',
#  'onepiece_cl1028.png',
#  'onepiece_cl480.png',
#  'blackclover_cl965.png',
#  'blackclover_cl540.png',
#  'onepiece_cl133.png',
#  'blackclover_cl597.png',
#  'bukonohero_cl15.png',
#  'blackclover_cl420.png',
#  'blackclover_cl352.png',
#  'bukonohero_cl768.png',
#  'blackclover_cl385.png',
#  'onepiece_cl29.png',
#  'blackclover_cl636.png',
#  'onepiece_cl245.png',
#  'bukonohero_cl230.png',
#  'onepiece_cl1148.png',
#  'blackclover_cl805.png',
#  'bukonohero_cl581.png',
#  'blackclover_cl179.png',
#  'onepiece_cl250.png',
#  'onepiece_cl1439.png',
#  'blackclover_cl390.png',
#  'onepiece_cl913.png',
#  'bukonohero_cl755.png',
#  'blackclover_cl421.png',
#  'bukonohero_cl184.png',
#  'onepiece_cl1217.png',
#  'blackclover_cl582.png',
#  'bukonohero_cl806.png',
#  'onepiece_cl654.png',
#  'bukonohero_cl621.png',
#  'bukonohero_cl635.png',
#  'onepiece_cl126.png',
#  'onepiece_cl640.png',
#  'blackclover_cl541.png',
#  'onepiece_cl495.png',
#  'blackclover_cl970.png',
#  'blackclover_cl780.png',
#  'blackclover_cl33.png',
#  'bukonohero_cl423.png',
#  'onepiece_cl330.png',
#  'bukonohero_cl345.png',
#  'onepiece_cl442.png',
#  'onepiece_cl324.png',
#  'onepiece_cl318.png',
#  'blackclover_cl999.png',
#  'blackclover_cl3.png',
#  'blackclover_cl31.png',
#  'blackclover_cl972.png',
#  'onepiece_cl483.png',
#  'blackclover_cl231.png',
#  'blackclover_cl557.png',
#  'onepiece_cl124.png',
#  'onepiece_cl865.png',
#  'bukonohero_cl810.png',
#  'onepiece_cl1215.png',
#  'onepiece_cl859.png',
#  'blackclover_cl437.png',
#  'onepiece_cl1361.png',
#  'blackclover_cl621.png',
#  'onepiece_cl508.png',
#  'bukonohero_cl233.png',
#  'blackclover_cl184.png',
#  'blackclover_cl191.png',
#  'onepiece_cl535.png',
#  'onepiece_cl247.png',
#  'blackclover_cl620.png',
#  'blackclover_cl146.png',
#  'blackclover_cl1060.png',
#  'bukonohero_cl568.png',
#  'bukonohero_cl795.png',
#  'onepiece_cl17.png',
#  'bukonohero_cl971.png',
#  'onepiece_cl737.png',
#  'bukonohero_cl839.png',
#  'bukonohero_cl17.png',
#  'onepiece_cl1214.png',
#  'onepiece_cl1228.png',
#  'blackclover_cl556.png',
#  'blackclover_cl973.png',
#  'blackclover_cl2.png',
#  'onepiece_cl333.png',
#  'bukonohero_cl408.png',
#  'blackclover_cl998.png',
#  'onepiece_cl451.png',
#  'bukonohero_cl356.png',
#  'onepiece_cl323.png',
#  'blackclover_cl988.png',
#  'blackclover_cl20.png',
#  'blackclover_cl787.png',
#  'blackclover_cl34.png',
#  'blackclover_cl220.png',
#  'bukonohero_cl168.png',
#  'bukonohero_cl197.png',
#  'bukonohero_cl801.png',
#  'blackclover_cl585.png',
#  'onepiece_cl1238.png',
#  'blackclover_cl354.png',
#  'bukonohero_cl949.png',
#  'onepiece_cl900.png',
#  'bukonohero_cl550.png',
#  'bukonohero_cl236.png',
#  'onepiece_cl531.png',
#  'bukonohero_cl544.png',
#  'blackclover_cl1064.png',
#  'blackclover_cl142.png',
#  'blackclover_cl817.png',
#  'bukonohero_cl579.png',
#  'blackclover_cl625.png',
#  'blackclover_cl157.png',
#  'onepiece_cl256.png',
#  'blackclover_cl619.png',
#  'onepiece_cl915.png',
#  'bukonohero_cl1046.png',
#  'onepiece_cl1403.png',
#  'blackclover_cl369.png',
#  'blackclover_cl590.png',
#  'onepiece_cl691.png',
#  'onepiece_cl849.png',
#  'bukonohero_cl141.png',
#  'blackclover_cl7.png',
#  'onepiece_cl322.png',
#  'bukonohero_cl425.png',
#  'blackclover_cl779.png',
#  'onepiece_cl336.png',
#  'bukonohero_cl343.png',
#  'onepiece_cl446.png',
#  'bukonohero_cl427.png',
#  'blackclover_cl753.png',
#  'onepiece_cl491.png',
#  'blackclover_cl784.png',
#  'onepiece_cl122.png',
#  'bukonohero_cl625.png',
#  'onepiece_cl136.png',
#  'onepiece_cl888.png',
#  'onepiece_cl678.png',
#  'blackclover_cl551.png',
#  'blackclover_cl545.png',
#  'onepiece_cl1213.png',
#  'blackclover_cl592.png',
#  'bukonohero_cl816.png',
#  'onepiece_cl877.png',
#  'blackclover_cl431.png',
#  'onepiece_cl1398.png',
#  'onepiece_cl718.png',
#  'bukonohero_cl786.png',
#  'onepiece_cl1367.png',
#  'bukonohero_cl792.png',
#  'onepiece_cl1401.png',
#  'onepiece_cl10.png',
#  'onepiece_cl903.png',
#  'bukonohero_cl1044.png',
#  'onepiece_cl268.png',
#  'onepiece_cl1165.png',
#  'onepiece_cl269.png',
#  'blackclover_cl140.png',
#  'blackclover_cl168.png',
#  'onepiece_cl527.png',
#  'onepiece_cl255.png',
#  'bukonohero_cl220.png',
#  'onepiece_cl533.png',
#  'onepiece_cl1366.png',
#  'onepiece_cl1414.png',
#  'onepiece_cl1372.png',
#  'bukonohero_cl11.png',
#  'onepiece_cl692.png',
#  'bukonohero_cl195.png',
#  'onepiece_cl1206.png',
#  'blackclover_cl578.png',
#  'bukonohero_cl156.png',
#  'blackclover_cl785.png',
#  'bukonohero_cl397.png',
#  'bukonohero_cl340.png',
#  'onepiece_cl447.png']
